# %%
import requests as r

# %%
q = r.get('http://tigerweb.geo.census.gov/arcgis/rest/services/TIGERweb')

# %%
[x for x in q.iter_lines()]
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '<html>',
#  '',
#  '<head>',
#  '<title>Folder: TIGERweb</title>',
#  '<link href="/arcgis/rest/static/main.css" rel="stylesheet" type="text/css"/>',
#  '</head>',
#  '',
#  '<body>',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '<table width="100%" class="userTable">',
#  ' <tr>',
#  ' <td class="titlecell">',
#  ' ArcGIS REST Services Directory',
#  ' </td>',
#  ' <td align="right">',
#  '   ',
#  '      ',
#  '        <a href="http://tigerweb.geo.census.gov/arcgis/rest/login">Login</a>',
#  '       ',
#  '            | <a href="https://tigerweb.geo.census.gov/arcgis/tokens/">Get Token</a>',
#  '                  ',
#  '      ',
#  '   ',
#  ' </td>',
#  ' </tr>',
#  '</table>',
#  '<table width="100%" class="navTable">',
#  '<tr valign="top">',
#  '<td class="breadcrumbs">',
#  '<a href="/arcgis/rest/services">Home</a>',
#  '',
#  '',
#  '',
# ...
